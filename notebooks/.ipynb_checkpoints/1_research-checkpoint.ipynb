# %%
import pandas as pd
import numpy as np
import sklearn

import os

# %% [markdown]
# ### Importing db1

# %%
path = os.getcwd()

# %%
fish_df = pd.read_csv(path + r"\data\db1\ref\fish.csv", error_bad_lines=False, sep=';')
prod_designate_df = pd.read_csv(path + r"\data\db1\ref\prod_designate.csv", error_bad_lines=False, sep=';')
prod_type_df = pd.read_csv(path + r"\data\db1\ref\prod_type.csv", error_bad_lines=False, sep=';')
regime_df = pd.read_csv(path + r"\data\db1\ref\regime.csv", error_bad_lines=False, sep=';')
region_df = pd.read_csv(path + r"\data\db1\ref\region.csv", error_bad_lines=False, sep=';')

# %%
catch_df = pd.read_csv(path + r'\data\db1\catch.csv', error_bad_lines=False, sep=',')
product_df = pd.read_csv(path + r'\data\db1\product.csv', error_bad_lines=False, sep=',')

# %% [markdown]
# ### Observing data

# %% [markdown]
# #### Support data

# %%
fish_df.head(5)
# Out:
#    id_fish                 fish
# 0        0         Не определен
# 1        1           макруронус
# 2        2  Рыбы и морепродукты
# 3        3                 Рыбы
# 4        4               сельди

# %%
prod_designate_df.head(5)
# Out:
#    id_prod_designate                                     prod_designate
# 0                  0                                       не определен
# 1                  1  рыбопродукция, выпущенная из собственного сырь...
# 2                  3        рыбопродукция, принятая для транспортировки
# 3                  4  рыбопродукция, принятая (купленная) для промпе...
# 4                  5  рыбопродукция из собств сырья, предназн для пр...

# %%
prod_type_df.head(5)
# Out:
#    id_prod_type                                          prod_type  id_fish  \
# 0          6060                                   Рыба охлажденная        2
# 1          9420                                    альгинат натрия       29
# 2          6010                            Пряный посол и маринады        2
# 3          6490                                    икра прочих рыб        2
# 4          8302  Рыба, морепродукты и отходы от разделки рыбы д...        2
#
#                                       prod_type_full
# 0                                   рыба охлажденная
# 1                                    альгинат натрия
# 2                            пряный посол и маринады
# 3                                    икра прочих рыб
# 4  рыба морепродукты и отходы от разделки рыбы дл...

# %%
regime_df.head(5)
# Out:
#    id_regime                                      regime
# 0          0                                не определен
# 1          1                            промышленный лов
# 2          3                        научные исследования
# 3         12                      прибрежное рыболовство
# 4         15  промысел для РФ по международным договорам

# %%
region_df.head(5)
# Out:
#    id_region     region
# 0       7010      Бирма
# 1       7009      Бенин
# 2       7008    Бельгия
# 3       7007   Барбадос
# 4       7006  Бангладеш

# %%
product_df
# Out:
#          id_ves        date  id_prod_designate  id_prod_type  prod_volume  \
# 0       1491364  2022-01-01                  1         10128        0.102
# 1       7014122  2022-01-01                  3          3901        0.000
# 2       8958321  2022-01-01                  1          1113        0.000
# 3       8958321  2022-01-01                  1          1135        0.000
# 4       8958321  2022-01-01                  1          4648        0.000
# ...         ...         ...                ...           ...          ...
# 395066  3156205  2022-04-20                  1          1027        0.000
# 395067  3156205  2022-04-20                  1          1055        0.000
# 395068  2467785  2022-04-20                  1          9661        0.044
# 395069  2467785  2022-04-20                  1          9660        9.394
# 395070  4992471  2022-04-20                  1          1092        0.000
#
#         prod_board_volume
# 0                   8.234
# 1                  42.780
# 2                   0.050
# 3                   4.300
# 4                   0.225
# ...                   ...
# 395066              0.000
# 395067              0.000
# 395068              5.589
# 395069             72.115
# 395070              0.045
#
# [395071 rows x 6 columns]

# %% [markdown]
# ## Main data

# %% [markdown]
# ### Подмена ID на текстовое название рыбы + приведение к нормальному виду

# %%
def spoofing(id):
    return fish_df[fish_df['id_fish'] == id]['fish'].values[0]
catch_df['id_fish'] = catch_df['id_fish'].apply(spoofing)
catch_df['catch_volume'] = catch_df['catch_volume']*1000

catch_df
# Out:
#         id_ves        date  id_region               id_fish  catch_volume  \
# 0      4524386  2022-01-01        272                минтай      31874.00
# 1       474886  2022-01-01        277  краб-стригун красный        476.00
# 2      3160994  2022-01-01        116    путассу (северная)      26310.00
# 3      1234400  2022-01-01        272                треска       9541.00
# 4      1234400  2022-01-01        272         палтус черный         62.00
# ...        ...         ...        ...                   ...           ...
# 85082  4992471  2022-04-20        108                 сайда       1166.00
# 85083  7645033  2022-04-20        265                треска       1345.00
# 85084  5951077  2022-04-20        507         палтус черный          4.00
# 85085  5292474  2022-04-20        206      окунь золотистый        505.05
# 85086  5292474  2022-04-20        206          окунь-клювач        227.36
#
#        id_regime   permit   id_own
# 0             41   852296  7115834
# 1              1  5401178  1809581
# 2             15  3869431  5258490
# 3              1  2169057  1809581
# 4              1  2169057  1809581
# ...          ...      ...      ...
# 85082         18  1518104  8379463
# 85083         97  1750243  1002633
# 85084         97  5099847   440996
# 85085         97   229919  7829965
# 85086         97   229919  7829965
#
# [85087 rows x 8 columns]

# %% [markdown]
# ### Importing db2

# %%
ext1 = pd.read_csv(path + r"\data\db2\Ext.csv", error_bad_lines=False, sep=',')
ext2 = pd.read_csv(path + r"\data\db2\Ext2.csv", error_bad_lines=False, sep=',')
ext2['date_vsd'] = ext2['date_vsd'].apply(lambda x: x[:10])

# %%
print(len(ext1))
ext1.head(5)
# Out:
# 3260798
#    id_fishery   id_own         date_fishery numPart  id_Plat   id_vsd  \
# 0     2208303  6493928  2022-05-24 00:00:00      \N  5022636  8745666
# 1     5538439  3846064  2022-05-24 00:00:00      \N   839830  3846313
# 2     8688535  3107158  2022-05-24 00:00:00      \N  9310751  5215676
# 3     8688535  3107158  2022-05-24 00:00:00      \N  9310751  4008716
# 4     9102536  6493928  2022-05-24 00:00:00      \N  2900344  8522784
#
#   Name_Plat Product_period Region_Plat
# 0        \N             \N          \N
# 1        \N             \N          \N
# 2        \N             \N          \N
# 3        \N             \N          \N
# 4        \N             \N          \N

# %%
print(len(ext2))
ext2.head(5)
# Out:
# 3115280
#     id_vsd  num_vsd  id_fish          fish             date_vsd  volume unit
# 0  7230988  8934601      400        минтай  2022-01-01 00:39:56   75480   \N
# 1  3420538  1439843      400        минтай  2022-01-01 01:34:08   62586   \N
# 2  9509257   342637      292        треска  2022-01-01 01:34:11    1155   \N
# 3  1894307  1801854      400        минтай  2022-01-01 01:34:05  111048   \N
# 4  9410489  3126516       88  окунь-клювач  2022-01-01 01:34:11    1844   \N

# %%
ext2['id_fish'].value_counts()
# Out:
# -1      3052828
#  292      10716
#  408       6585
#  400       6318
#  610       4454
#          ...
#  863          1
#  302          1
#  383          1
#  713          1
#  469          1
# Name: id_fish, Length: 79, dtype: int64

# %% [markdown]
# ### Vizualizing dataset

# %%
import seaborn as sns
sns.heatmap(catch_df.corr())
# Out:
# <AxesSubplot:>

# %%
fish_df
# Out:
#      id_fish                          fish
# 0          0                  Не определен
# 1          1                    макруронус
# 2          2           Рыбы и морепродукты
# 3          3                          Рыбы
# 4          4                        сельди
# ..       ...                           ...
# 817      443      лещи морские серебристые
# 818      172  скат колючий, лисица морская
# 819      174                скаты песчаные
# 820      494                       керчаки
# 821      854    краб красный глубоководный
#
# [822 rows x 2 columns]

# %%
dates = catch_df['date'].unique()
Y = dates.copy()
Total_X1 = []
Total_X2 = []

fish =  fish_df[fish_df['id_fish'] == 400]['fish'].values[0]
X1 = catch_df[catch_df['id_fish'] == fish]
X2 = ext2[ext2['fish'] == fish]

for date in dates:
    X1_dated = X1[X1['date'] == date]['catch_volume'].sum()
    X2_dated = X2[X2['date_vsd'] == date]['volume'].sum()
    
    Total_X1.append(X1_dated)
    Total_X2.append(X2_dated)

# %%
hue = []
total_x = Total_X1.extend(Total_X2)
for x in total_x:
    if x in Total_X1:
        hue.append('db1')
    elif x in Total_X2:
        hue.append('db2')

# %%
sns.scatterplot(y=Total_X1, x=dates)
# Out:
# <AxesSubplot:>

# %%
Total_X2
# Out:
# [1588126,
#  2906240,
#  2529665,
#  3616363,
#  2108845,
#  6654078,
#  4958405,
#  3554870,
#  3116567,
#  7587986,
#  4621852,
#  7606622,
#  5364163,
#  6780748,
#  4373796,
#  2647611,
#  4978520,
#  5790267,
#  6383131,
#  5363489,
#  5453683,
#  4424062,
#  4604846,
#  8064408,
#  11054172,
#  6649039,
#  2223913,
#  11885441,
#  5334018,
#  6048368,
#  10763359,
#  9219912,
#  5959572,
#  7778398,
#  9210105,
#  4648022,
#  4297250,
#  11009038,
#  9672529,
#  11637792,
#  8350939,
#  12377053,
#  9907810,
#  6021362,
#  8892228,
#  7030529,
#  10135149,
#  8630756,
#  8109040,
#  6471229,
#  6163361,
#  11264712,
#  8857418,
#  3223783,
#  2738906,
#  6366539,
#  4352977,
#  8086971,
#  13510147,
#  12864073,
#  8651641,
#  10667196,
#  12545323,
#  12834418,
#  5878388,
#  8549993,
#  6855987,
#  17187979,
#  5531602,
#  11359889,
#  8163806,
#  9056486,
#  12149624,
#  9902939,
#  10130964,
#  12395744,
#  8743954,
#  7005438,
#  8305221,
#  13562227,
#  7167097,
#  6188077,
#  9081163,
#  9912772,
#  7210490,
#  6916848,
#  10886214,
#  9393731,
#  6091010,
#  8036198,
#  9852516,
#  2959397,
#  6078742,
#  9255527,
#  9995413,
#  7283266,
#  8431389,
#  8900175,
#  7344382,
#  7279946,
#  5388257,
#  2893558,
#  3801394,
#  2595118,
#  2465539,
#  1212579,
#  1206122,
#  3159119,
#  2178205,
#  974377]

# %%
X = catch_df['catch_volume']
Y = ext2['']
# Out:
#         id_ves        date  id_region  id_fish  catch_volume  id_regime  \
# 0      4524386  2022-01-01        272      400      31874.00         41
# 1       474886  2022-01-01        277      886        476.00          1
# 2      3160994  2022-01-01        116      409      26310.00         15
# 3      1234400  2022-01-01        272      292       9541.00          1
# 4      1234400  2022-01-01        272      113         62.00          1
# ...        ...         ...        ...      ...           ...        ...
# 85082  4992471  2022-04-20        108      410       1166.00         18
# 85083  7645033  2022-04-20        265      292       1345.00         97
# 85084  5951077  2022-04-20        507      113          4.00         97
# 85085  5292474  2022-04-20        206      147        505.05         97
# 85086  5292474  2022-04-20        206       88        227.36         97
#
#         permit   id_own
# 0       852296  7115834
# 1      5401178  1809581
# 2      3869431  5258490
# 3      2169057  1809581
# 4      2169057  1809581
# ...        ...      ...
# 85082  1518104  8379463
# 85083  1750243  1002633
# 85084  5099847   440996
# 85085   229919  7829965
# 85086   229919  7829965
#
# [85087 rows x 8 columns]
